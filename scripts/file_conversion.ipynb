# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
chunk_size = 1000000
chunks = []
for chunk in  pd.read_csv('../data/Bronze/HI-Medium_Trans.csv', chunksize=chunk_size):
    chunks.append(chunk)
df = pd.concat(chunks, ignore_index=True)

df.to_parquet('../data/Bronze/HI-Medium_Trans.parquet', engine='pyarrow', compression='snappy')
